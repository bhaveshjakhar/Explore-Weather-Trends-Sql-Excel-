# %% [markdown]
# # Importing neccessary libraries for the project :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Importing the data!

# %%
globaltemp = pd.read_csv('globaldata.csv')
citytemp = pd.read_csv('results.csv')

# %% [markdown]
# ## Doing 'Moving Average' for the Global data and Local data

# %%
glb_mv_avg = globaltemp['avg_temp'].rolling(10).mean()
local_mv_avg = citytemp['avg_temp'].rolling(10).mean()

# %% [markdown]
# ## Visualizng Data using matplotlib Library.

# %%
plt.plot(globaltemp['year'],glb_mv_avg,label='Global')
plt.plot(citytemp['year'],local_mv_avg,label='Delhi')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Delhi City Average Temperature")
plt.show()
